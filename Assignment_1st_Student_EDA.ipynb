# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Student_Performance (2).csv")

# %%
df.shape
# Out:
# (10000, 6)

# %% [markdown]
# It tells us about the no of rows and columns of the data set

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %% [markdown]
# It tell us about the top 5 rows of the data set

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %% [markdown]
# It tell us about last 5 rows of the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %% [markdown]
# It tell us about the infomation of our dataset it's rows,columns data types,is there any null value or not

# %%
df.describe().T
# Out:
#                                     count     mean        std   min   25%  \
# Hours Studied                     10000.0   4.9929   2.589309   1.0   3.0
# Previous Scores                   10000.0  69.4457  17.343152  40.0  54.0
# Sleep Hours                       10000.0   6.5306   1.695863   4.0   5.0
# Sample Question Papers Practiced  10000.0   4.5833   2.867348   0.0   2.0
# Performance Index                 10000.0  55.2248  19.212558  10.0  40.0
#
#                                    50%   75%    max
# Hours Studied                      5.0   7.0    9.0
# Previous Scores                   69.0  85.0   99.0
# Sleep Hours                        7.0   8.0    9.0
# Sample Question Papers Practiced   5.0   7.0    9.0
# Performance Index                 55.0  71.0  100.0

# %% [markdown]
# It will tell us about some values without writing any formula

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# It tell us about the no of empty rows values in our columns

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %% [markdown]
# It tell us about all

# %%
df["Extracurricular Activities"].value_counts()
# Out:
# Extracurricular Activities
# No     5052
# Yes    4948
# Name: count, dtype: int64

# %% [markdown]
# It tell us about the count of students who are involved in extracurricular activities

# %%
df["Sleep Hours"].value_counts()
# Out:
# Sleep Hours
# 8    1804
# 7    1676
# 6    1673
# 9    1622
# 4    1619
# 5    1606
# Name: count, dtype: int64

# %% [markdown]
# It tell us about count of no of students sleep hours
#
# it tells us about 1804 students sleep 8 hours which tells us how many students sleep how many hours max so our answer is 8

# %% [markdown]
# # Univeriate

# %%
sns.barplot(df["Sleep Hours"].value_counts())
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='count'>

# %% [markdown]
# # Observation
# This plot tells us about the count of students sleep hours most of the students sleep 8hours  then 6 and 7 hours and 9 hours sleep students is lowest

# %%
sns.kdeplot(df["Previous Scores"])
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Density'>

# %% [markdown]
# # Observation
# This plot tell us about the density of our data in the particular range which is previous score  between 50-60 the density is higher then 60-90 it start bending then in 100-110 it goes down

# %%
sns.kdeplot(df["Previous Scores"])
sns.rugplot(df["Previous Scores"])
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Density'>

# %% [markdown]
# # Observation
# This graph tells us about how much students sccores in previous exam their density is higer in 90
#
# and the rug plot help us to see the values which are under 3 std and for the remaining data it not show the sticks are outliers

# %%
sns.displot(df["Previous Scores"],kde=True)

# %% [markdown]
# # Observation
# This plot tell us about the previous scores of students  distributedin the intervals of 10-10 bins so we can see the no of students distributed in our dataset
# and kde plot shows the smothness of distrubtion in distribution plot

# %%
sns.histplot(df["Performance Index"])
# Out:
# <Axes: xlabel='Performance Index', ylabel='Count'>

# %% [markdown]
# # Observation
# This plot tell us about the performance index of students in the range to easier understand the shape of their perfomance index in which range it is higher and in which it is going lower most of the students performance index higer in between 40-60

# %%
sns.boxplot(data=df,x=df["Performance Index"],width=0.6)
# Out:
# <Axes: xlabel='Performance Index'>

# %% [markdown]
# # Observation
# This plot tell us the all the auartiles of the performance index and iqr by the height of the box

# %%
sns.countplot(df["Extracurricular Activities"])
# Out:
# <Axes: xlabel='count', ylabel='Extracurricular Activities'>

# %% [markdown]
# # Observation
# This tell us about the count of the no of students involved in extra curricular activities
# There are more students who don't do extra curricular activities

# %%
sns.displot(df["Sleep Hours"],kind="ecdf")

# %%
sns.displot(df["Sleep Hours"], kde=True,rug=True)

# %% [markdown]
# # Observation
# This tell us about students sleep hours pattern,most common sleep hours of students here we can see how much the sleep hours are varing no of students prefer 8 hours of sleep and the kde curve also goes a bit up there

# %% [markdown]
# # Biveriate

# %%
sns.lineplot(x=df["Sleep Hours"],y=df["Performance Index"])
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %% [markdown]
# # Observation
# This tell us about the slepp hours of student with respect to their perforance index so we can see sleep hours increasing the performance increasing or decreasing
#
# Here students sleep 5 hours their performance is going down and other students performace is increasing

# %%
sns.displot(data=df,x="Performance Index",y="Previous Scores",kind="kde")

# %% [markdown]
# # Observation
# This plot tell us about that the students performance is index is good with their marks or not
# the kde plot is filling colors on the area where the density of students is higher like in 40-60 performace index students have scores between 40-60

# %%
sns.scatterplot(data=df,x="Performance Index",y="Previous Scores",hue="Extracurricular Activities")
# Out:
# <Axes: xlabel='Performance Index', ylabel='Previous Scores'>

# %% [markdown]
# # observation
# This plot tell us about students perfomace index with respect to their previous score and that student is involved in extracurricular activities or not

# %%
sns.scatterplot(data=df, x="Hours Studied", y="Sleep Hours", hue="Extracurricular Activities")
plt.legend(fontsize='small', loc='upper left', bbox_to_anchor=(1.05, 1))

# %% [markdown]
# # Observation
# This tell us the students who involved or not involved in extracurricular activites how much they sleep and studied
# here you can see students who sleep 9 hours are not that much involved in other activities and students who slept 4 hours are more involved in it no matter how much they studied 1,2 or 7 hours only 9 hours studying students isn't involved and rest are

# %%
sns.scatterplot(data=df, x="Hours Studied", y="Previous Scores", hue="Sleep Hours", palette="deep")
plt.legend(loc=2, markerscale=0.9,fontsize=9)

# %% [markdown]
# # Observation
#  This plot tell us about the students previous score with respect to hours studied with their sleep hours

# %%
sns.boxplot(data=df,x=df["Sleep Hours"],y=df["Performance Index"],width=0.5)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %% [markdown]
# # Observation
# This plot tell us the median of all students performance index according to their sleep hours
# like the median of all hours students sleep is between 60-40

# %%
sns.violinplot(data=df,x=df["Sleep Hours"],y=df["Previous Scores"],width=0.5)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Previous Scores'>

# %% [markdown]
# # Observation
# This tell us about the students previous scores according to their sleep hours the shape of the violin tells the density where is higher and where is lower

# %% [markdown]
# # Multivariate

# %%
sns.pairplot(data=df, hue="Sleep Hours")

# %% [markdown]
# # Observation
# This help us to unerstand how sleep hows are related to other columns and values
# is there any pattern between them or any thing which is wrong in the data

# %%
data=df.pivot( columns="Sample Question Papers Practiced", values="Previous Scores")
sns.heatmap(data)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced'>

# %% [markdown]
# # Oservation
# This tell us the difference between students of different different ranges and their scores as per their no of sample paper practiced
