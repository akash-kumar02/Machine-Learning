# %%
import pandas as pd

# %%
df=pd.read_csv("titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df_row_del=df.dropna(axis=0)
df_row_del["Age"].head(6)
# Out:
# 1     38.0
# 3     35.0
# 6     54.0
# 10     4.0
# 11    58.0
# 21    34.0
# Name: Age, dtype: float64

# %%
df.shape, df_row_del.shape
# Out:
# ((891, 12), (183, 12))

# %%
# isnull with ratio
(df.isnull().sum())/891
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df_col_del=df.dropna(thresh=500,axis=1)
df_col_del.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.shape, df_col_del.shape
# Out:
# ((891, 12), (891, 11))

# %%
df["Cabin"].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
df["Cabin"].fillna(value="missing")
# Out:
# 0      missing
# 1          C85
# 2      missing
# 3         C123
# 4      missing
#         ...
# 886    missing
# 887        B42
# 888    missing
# 889       C148
# 890    missing
# Name: Cabin, Length: 891, dtype: object

# %%
df["Age"].fillna(value=999)
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#        ...
# 886     27.0
# 887     19.0
# 888    999.0
# 889     26.0
# 890     32.0
# Name: Age, Length: 891, dtype: float64

# %%
# make a copy
data_replace=df.copy()
# replace value
data_replace["Age"]=data_replace["Age"].fillna(value=999)
data_replace.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df["Cabin"].isnull()).astype("int")
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    1
# 889    0
# 890    1
# Name: Cabin, Length: 891, dtype: int64

# %%
data_replace.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# finding mean value
mean_val=df["Age"].mean()
mean_val
# Out:
# np.float64(29.69911764705882)

# %%
# making a copy
data_cleaned=df.copy()
# inputting missing values
data_cleaned["Age"]=df["Age"].fillna(value=mean_val)
data_cleaned["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
mode_val=df["Embarked"].mode()[0]
mode_val
# Out:
# 'S'

# %%
data_cleaned["Embarked"]=df["Embarked"].fillna(value=mode_val)
data_cleaned
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
categorical_cols = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df[categorical_cols].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
pd.get_dummies(df['Embarked']).head()
# Out:
#        C      Q      S
# 0  False  False   True
# 1   True  False  False
# 2  False  False   True
# 3  False  False   True
# 4  False  False   True

# %%
data_cleaned = pd.get_dummies(data_cleaned)
data_cleaned.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
#
#    Name_Abbing, Mr. Anthony  Name_Abbott, Mr. Rossmore Edward  \
# 0                     False                             False
# 1                     False                             False
# 2                     False                             False
# 3                     False                             False
# 4                     False                             False
#
#    Name_Abbott, Mrs. Stanton (Rosa Hunt)  ...  Cabin_F G73  Cabin_F2  \
# 0                                  False  ...        False     False
# 1                                  False  ...        False     False
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# map functions
df['Embarked'].map({'Q': 0, 'S': 1, 'C':2})
# Out:
# 0      1.0
# 1      2.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 886    1.0
# 887    1.0
# 888    1.0
# 889    2.0
# 890    0.0
# Name: Embarked, Length: 891, dtype: float64

# %%
df['Embarked'] = df['Embarked'].map({'Q': 0, 'S': 1, 'C':2})
df['Embarked'].head()
# Out:
# 0    1.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Embarked, dtype: float64
