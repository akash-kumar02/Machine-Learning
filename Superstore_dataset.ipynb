# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Superstore_data.csv")

# %%
df.head()
# Out:
#    Row ID         Category Sub-Category     Sales  Quantity  Discount  \
# 0       1        Furniture    Bookcases  261.9600         2      0.00
# 1       2        Furniture       Chairs  731.9400         3      0.00
# 2       3  Office Supplies       Labels   14.6200         2      0.00
# 3       4        Furniture       Tables  957.5775         5      0.45
# 4       5  Office Supplies      Storage   22.3680         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
df.tail()
# Out:
#       Row ID         Category Sub-Category    Sales  Quantity  Discount  \
# 9989    9990        Furniture  Furnishings   25.248         3       0.2
# 9990    9991        Furniture  Furnishings   91.960         2       0.0
# 9991    9992       Technology       Phones  258.576         2       0.2
# 9992    9993  Office Supplies        Paper   29.600         4       0.0
# 9993    9994  Office Supplies   Appliances  243.160         2       0.0
#
#        Profit
# 9989   4.1028
# 9990  15.6332
# 9991  19.3932
# 9992  13.3200
# 9993  72.9480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Category      9994 non-null   object
#  2   Sub-Category  9994 non-null   object
#  3   Sales         9994 non-null   float64
#  4   Quantity      9994 non-null   int64
#  5   Discount      9994 non-null   float64
#  6   Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 546.7+ KB

# %%
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 7)

# %%
df.isnull()
# Out:
#       Row ID  Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0      False     False         False  False     False     False   False
# 1      False     False         False  False     False     False   False
# 2      False     False         False  False     False     False   False
# 3      False     False         False  False     False     False   False
# 4      False     False         False  False     False     False   False
# ...      ...       ...           ...    ...       ...       ...     ...
# 9989   False     False         False  False     False     False   False
# 9990   False     False         False  False     False     False   False
# 9991   False     False         False  False     False     False   False
# 9992   False     False         False  False     False     False   False
# 9993   False     False         False  False     False     False   False
#
# [9994 rows x 7 columns]

# %%
df.describe().T
# Out:
#            count         mean          std       min         25%        50%  \
# Row ID    9994.0  4997.500000  2885.163629     1.000  2499.25000  4997.5000
# Sales     9994.0   229.858001   623.245101     0.444    17.28000    54.4900
# Quantity  9994.0     3.789574     2.225110     1.000     2.00000     3.0000
# Discount  9994.0     0.156203     0.206452     0.000     0.00000     0.2000
# Profit    9994.0    28.656896   234.260108 -6599.978     1.72875     8.6665
#
#                75%        max
# Row ID    7495.750   9994.000
# Sales      209.940  22638.480
# Quantity     5.000     14.000
# Discount     0.200      0.800
# Profit      29.364   8399.976

# %%
df.isnull().sum()
# Out:
# Row ID          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(df,x="Row ID")

# %%
sns.displot(df,x="Category")

# %%
sns.histplot(df,x="Sub-Category")
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Count'>

# %%
sns.scatterplot(df["Discount"])
# Out:
# <Axes: ylabel='Discount'>

# %%
sns.scatterplot(df["Profit"])
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.relplot(df["Quantity"])

# %%
sns.lineplot(df["Profit"])
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.kdeplot(df["Sales"])
# Out:
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sns.kdeplot(df["Discount"])
# Out:
# <Axes: xlabel='Discount', ylabel='Density'>

# %%
sns.boxplot(df["Quantity"])
# Out:
# <Axes: ylabel='Quantity'>

# %%
sns.boxplot(df["Row ID"])
# Out:
# <Axes: ylabel='Row ID'>

# %%
sns.violinplot(df["Discount"])
# Out:
# <Axes: ylabel='Discount'>

# %%
sns.displot(df,x="Row ID",y="Sales")

# %%
sns.histplot(df,x="Discount",y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.barplot(df,x="Category",y="Sub-Category")
# Out:
# <Axes: xlabel='Category', ylabel='Sub-Category'>

# %%
sns.scatterplot(df,x="Row ID",y="Sales")
# Out:
# <Axes: xlabel='Row ID', ylabel='Sales'>

# %%
sns.relplot(df,x="Category",y="Sub-Category")

# %%
sns.lineplot(df,x="Discount",y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.kdeplot(df,x="Quantity",y="Discount")
# Out:
# <Axes: xlabel='Quantity', ylabel='Discount'>

# %%
sns.boxplot(df,x="Discount",y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.violinplot(df,x="Sales",y="Discount")
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>
